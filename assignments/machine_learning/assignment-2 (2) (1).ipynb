# %% [markdown]
# # Assignment-2, Big Data Intr. and Analysis
# # 作业-2，大数据入门与分析

# %% [markdown]
# 本作业共150分, 占期末总分的20%。
#
# 在你完成本作业时，请先把需要的数据集文件上传到相应的“文件”空间里！
#
# 姓名：
#
# 学号：

# %% [markdown]
# ## Module 1, 模块 1

# %%
# Make sure you have required modules installed.
# !pip install -U scikit-learn
# !pip install numpy
# !pip install pandas

# %% [markdown]
# ### Import required modules and load data file

# %% [markdown]
# For this assignment, you will be using the Breast Cancer Wisconsin (Diagnostic) Database to create a classifier that can help diagnose patients. First, read through the description of the dataset (below).
#
# The object returned by `load_breast_cancer()` is a scikit-learn Bunch object, which is similar to a dictionary.
#
# 本次作业将使用威斯康星州乳腺癌（诊断）数据库创建一个分类器，用于帮助诊断患者。首先，请阅读数据集的描述（如下）。
#
# `load_breast_cancer()` 返回的对象是一个 scikit-learn Bunch 对象，类似于字典。

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer

cancer = load_breast_cancer()

print(cancer.DESCR) # Print the data set description

# %%
cancer.keys()

# %% [markdown]
# ### Question 0 (Example) (0 pt)
#
# How many features does the breast cancer dataset have?
#
# *This function should return an integer.*
#
# Note that after finishing your code, please remove `raise NotImplementedError()` statement in the code for correct execution.
#
# 乳腺癌数据集有多少个特征？
#
# *此函数应返回一个整数。*
#
# 请注意，完成代码后，请删除代码中的`raise NotImplementedError()`语句以确保正确执行。
# 包括后续的所有程序。

# %%
# You should write your whole answer within the function provided. The autograder will call
# this function and compare the return value against the correct solution value
def answer_zero():
    # This function returns the number of features of the breast cancer dataset, which is an integer. 

    # YOUR CODE HERE
    re = len(cancer.get('data')[0])
    # raise NotImplementedError()
    return re

answer_zero()

# %% [markdown]
# ### Question 1 （5 pt）
#
# Scikit-learn works with lists, numpy arrays, scipy-sparse matrices, and pandas DataFrames, so converting the dataset to a DataFrame is not necessary for training this model. Using a DataFrame does however help make many things easier such as munging data, so let's practice creating a classifier with a pandas DataFrame.
#
#
#
# Convert the sklearn.dataset `cancer` to a DataFrame.
#
# * This function should return a `(569, 31)` DataFrame with *
#
# * columns = *
#
#     ['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#     'mean smoothness', 'mean compactness', 'mean concavity',
#     'mean concave points', 'mean symmetry', 'mean fractal dimension',
#     'radius error', 'texture error', 'perimeter error', 'area error',
#     'smoothness error', 'compactness error', 'concavity error',
#     'concave points error', 'symmetry error', 'fractal dimension error',
#     'worst radius', 'worst texture', 'worst perimeter', 'worst area',
#     'worst smoothness', 'worst compactness', 'worst concavity',
#     'worst concave points', 'worst symmetry', 'worst fractal dimension',
#     'target']
#
# * and index = *
#
#     RangeIndex(start=0, stop=569, step=1)
#
# ### 问题 1
#
# Scikit-learn 支持列表、numpy 数组、scipy-sparse 矩阵和 pandas DataFrame，因此训练此模型时无需将数据集转换为 DataFrame。不过，使用 DataFrame 确实可以简化许多操作，例如处理数据，所以让我们练习使用 pandas DataFrame 创建一个分类器。
#
# 在`answer_one()`中，请写代码将 sklearn.dataset `cancer` 转换为 DataFrame。
#
# * 此函数应返回一个 `(569, 31)` DataFrame，其中包含 *
#
# * columns = *
#
# ['平均半径', '平均纹理', '平均周长', '平均面积',
# '平均平滑度', '平均致密度', '平均凹度',
# '平均凹点数', '平均对称度', '平均分形维数',
# '半径误差', '纹理误差', '周长误差', '面积误差',
# '平滑度误差', '致密度误差', '凹度误差',
# '凹点数误差', '对称度误差', '分形维数误差',
# '最差半径', '最差纹理', '最差周长', '最差面积',
# '最差平滑度', '最差致密度', '最差凹度',
# '最差凹点', '最差对称性', '最差分形维数',
# '目标']
#
# * 和索引 = *
#
# RangeIndex(start=0, stop=569, step=1)

# %%
def answer_one():
    # YOUR CODE HERE

    raise NotImplementedError()
    return re

answer_one()

# %% [markdown]
# ### Question 2 （5 pt）
# What is the class distribution? (i.e. how many instances of `malignant` and how many `benign`?)
#
# *This function should return a Series named `target` of length 2 with integer values and index =* `['malignant', 'benign']`
#
# 类别分布是什么？（例如，有多少个“恶性”实例和多少个“良性”实例？）
#
# *此函数应返回一个名为“target”的序列，长度为 2，包含整数值，索引 =* `['恶性', '良性']`

# %%
def answer_two():
    # YOUR CODE HERE
    
    raise NotImplementedError()
    return re
answer_two()

# %% [markdown]
# ### Question 3 （5 pt）
# Split the DataFrame into `X` (the data) and `y` (the labels).
#
# *This function should return a tuple of length 2:* `(X, y)`*, where*
# * `X` *has shape* `(569, 30)`
# * `y` *has shape* `(569,)`.### Examining the data
#
# 将 DataFrame 拆分为 `X`（数据）和 `y`（标签）。
#
# *此函数应返回一个长度为 2 的元组：* `(X, y)`*，其中*
# * `X` *形状为* `(569, 30)`
# * `y` *形状为* `(569,)`。### 检查数据

# %%
def answer_three():
    # YOUR CODE HERE

    raise NotImplementedError()
answer_three()

# %% [markdown]
# ### Question 4 （5 pt）
# Using `train_test_split`, split `X` and `y` into training and test sets `(X_train, X_test, y_train, and y_test)`.
#
# **Set the random number generator state to 0 using `random_state=0` to make sure your results match the autograder!**
#
# *This function should return a tuple of length 4:* `(X_train, X_test, y_train, y_test)`*, where*
# * `X_train` *has shape* `(426, 30)`
# * `X_test` *has shape* `(143, 30)`
# * `y_train` *has shape* `(426,)`
# * `y_test` *has shape* `(143,)`
#
# ### 问题 4
# 使用 `train_test_split` 将 `X` 和 `y` 拆分为训练集和测试集 `(X_train, X_test, y_train, y_test)`。
#
# **使用 `random_state=0` 将随机数生成器状态设置为 0，以确保结果与自动评分器一致！**
#
# *此函数应返回一个长度为 4 的元组：* `(X_train, X_test, y_train, y_test)`，其中*
# * `X_train` *形状为 * `(426, 30)`
# * `X_test` *形状为 * `(143, 30)`
# * `y_train` *形状为 * `(426,)`
# * `y_test` *形状为 * `(143,)`

# %%
from sklearn.model_selection import train_test_split

def answer_four():
    # YOUR CODE HERE

    raise NotImplementedError()

answer_four()

# %% [markdown]
# ### Question 5 （10 pt）
# Using KNeighborsClassifier, fit a k-nearest neighbors (knn) classifier with `X_train`, `y_train` and using one nearest neighbor (`n_neighbors = 1`).
#
# *This function should return a `sklearn.neighbors.classification.KNeighborsClassifier`.
#
# ### 问题 5
# 使用 KNeighborsClassifier，拟合一个包含 `X_train`、`y_train` 和单个最近邻 (`n_neighbors = 1`) 的 k 最近邻 (knn) 分类器。
#
# *此函数应返回一个 `sklearn.neighbors.classification.KNeighborsClassifier`。

# %%
from sklearn.neighbors import KNeighborsClassifier

def answer_five():
    # YOUR CODE HERE

    raise NotImplementedError()

answer_five()

# %% [markdown]
# ### Question 6 （10 pt）
# Using your knn classifier, predict the class label using the mean value for each feature.
#
# Hint: You can use `cancerdf.mean()[:-1].values.reshape(1, -1)` which gets the mean value for each feature, ignores the target column, and reshapes the data from 1 dimension to 2 (necessary for the precict method of KNeighborsClassifier).
#
# ### 问题 6
# 使用你的 KNN 分类器，根据每个特征的平均值预测类标签。
#
# 提示：你可以使用 `cancerdf.mean()[:-1].values.reshape(1, -1)`，它会获取每个特征的平均值，忽略目标列，并将数据从 1 维重塑为 2 维（这是 KNeighborsClassifier 的 precict 方法所必需的）。

# %%
def answer_six():
    # YOUR CODE HERE

    raise NotImplementedError()

answer_six()

# %% [markdown]
# ### Question 7 （10 pt）
# Using your knn classifier, predict the class labels for the test set `X_test`.
#
# *This function should return a numpy array with shape `(143,)` and values either `0.0` or `1.0`.*
#
# ### 问题 7
# 使用你的 KNN 分类器，预测测试集“X_test”的类别标签。
#
# *此函数应返回一个形状为“(143,)”且值为“0.0”或“1.0”的 NumPy 数组。*

# %%
def answer_seven():
    # YOUR CODE HERE

    raise NotImplementedError()

answer_seven()

# %% [markdown]
# ### Question 8 （10 pt）
# Find the score (mean accuracy) of your knn classifier using `X_test` and `y_test`.
#
# *This function should return a float between 0 and 1*
#
# ### 问题 8
# 使用 `X_test` 和 `y_test` 计算你的 KNN 分类器的得分（平均准确率）。
#
# *此函数应返回 0 到 1 之间的浮点数*

# %%
def answer_eight():
    # YOUR CODE HERE

    raise NotImplementedError()

answer_eight()

# %% [markdown]
# ## Module 2, 模块2

# %% [markdown]
# In this module, you'll explore the relationship between model complexity and generalization performance, by adjusting key parameters of various supervised learning models. Part 1 of this assignment will look at regression and Part 2 will look at classification.
# ### Part 1 - Regression 第一部分

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split


np.random.seed(0)
n = 15
x = np.linspace(0,10,n) + np.random.randn(n)/5
y = np.sin(x)+x/6 + np.random.randn(n)/10


X_train, X_test, y_train, y_test = train_test_split(x, y, random_state=0)

def intro():
    # %matplotlib inline

    plt.figure()
    plt.scatter(X_train, y_train, label='training data')
    plt.scatter(X_test, y_test, label='test data')
    plt.legend(loc=4);

intro()

# %% [markdown]
# ### Question 1 （15 pt）
#
# Write a function that fits a polynomial LinearRegression model on the *training data* `X_train` for degrees 1, 3, 6, and 9. (Use PolynomialFeatures in sklearn.preprocessing to create the polynomial features and then fit a linear regression model) For each model, find 100 predicted values over the interval x = 0 to 10 (e.g. `np.linspace(0,10,100)`) and store this in a numpy array. The first row of this array should correspond to the output from the model trained on degree 1, the second row degree 3, the third row degree 6, and the fourth row degree 9.
#
# <img src="polynomialreg1.png" style="width: 1000px;"/>
#
# The figure above shows the fitted models plotted on top of the original data (using `plot_one()`).
#
# <br>
# *This function should return a numpy array with shape `(4, 100)`*
#
# ### 问题 1
#
# 编写一个函数，使用*训练数据* `X_train` 拟合多项式线性回归模型，其中阶数分别为 1、3、6 和 9。（使用 sklearn.preprocessing 中的 PolynomialFeatures 创建多项式特征，然后拟合线性回归模型）对于每个模型，在 x = 0 到 10 的区间内找到 100 个预测值（例如 `np.linspace(0,10,100)`），并将其存储在一个 NumPy 数组中。该数组的第一行应对应于在阶数为 1 的模型上训练的输出，第二行对应于阶数为 3 的模型，第三行对应于阶数为 6 的模型，第四行对应于阶数为 9 的模型。
#
# <img src="polynomialreg1.png" style="width: 1000px;"/>
#
# 上图显示了拟合模型在原始数据上绘制的结果（使用 `plot_one()`）。
#
# <br>
# *此函数应返回一个形状为 `(4, 100)` 的 NumPy 数组*

# %%
def answer_one():
    from sklearn.linear_model import LinearRegression
    from sklearn.preprocessing import PolynomialFeatures
    
    degree_predictions = np.zeros((4,100))
    
    # YOUR CODE HERE

    return degree_predictions

# %%
# feel free to use the function plot_one() to replicate the figure 
# from the prompt once you have completed question one
def plot_one(degree_predictions):
    plt.figure(figsize=(10,5))
    plt.plot(X_train, y_train, 'o', label='training data', markersize=10)
    plt.plot(X_test, y_test, 'o', label='test data', markersize=10)
    for i,degree in enumerate([1,3,6,9]):
        plt.plot(np.linspace(0,10,100), degree_predictions[i], alpha=0.8, lw=2, label='degree={}'.format(degree))
    plt.ylim(-1,2.5)
    plt.legend(loc=4)

plot_one(answer_one())

# %% [markdown]
# ### Question 2 （15 pt）
#
# Write a function that fits a polynomial LinearRegression model on the training data `X_train` for degrees 0 through 9. For each model compute the $R^2$ (coefficient of determination) regression score on the training data as well as the the test data, and return both of these arrays in a tuple.
#
# *This function should return a tuple of numpy arrays `(r2_train, r2_test)`. Both arrays should have shape `(10,)`*
#
# ### 问题 2
#
# 编写一个函数，对训练数据“X_train”进行多项式线性回归模型拟合，拟合度为 0 到 9 的多项式线性回归模型。计算每个模型在训练数据和测试数据上的 $R^2$（判定系数）回归得分，并将这两个数组以元组的形式返回。
#
# *此函数应返回一个包含 numpy 数组“(r2_train, r2_test)”的元组。这两个数组的形状均为“(10,)”*

# %%
def answer_two():
    from sklearn.linear_model import LinearRegression
    from sklearn.preprocessing import PolynomialFeatures
    from sklearn.metrics import r2_score

    r2_train = np.array([])
    r2_test = np.array([])
    
    # YOUR CODE HERE

answer_two()

# %% [markdown]
# ### Question 3 (15 pt)
#
# Based on the $R^2$ scores from question 2 (degree levels 0 through 9), what degree level corresponds to a model that is underfitting? What degree level corresponds to a model that is overfitting? What choice of degree level would provide a model with good generalization performance on this dataset?
#
# (Hint: Try plotting the $R^2$ scores from question 2 to visualize the relationship)
#
# *This function should return a tuple with the degree values in this order: `(Underfitting, Overfitting, Good_Generalization)`*
#
# ### 问题 3
#
# 根据问题 2 中的 $R^2$ 得分（度数从 0 到 9），哪个度数对应欠拟合的模型？哪个度数对应过拟合的模型？哪种度数能够使模型在该数据集上具有良好的泛化性能？
#
# （提示：尝试绘制问题 2 中的 $R^2$ 得分，以直观地展示两者之间的关系）
#
# *此函数应返回一个度数值按以下顺序排列的元组：`(欠拟合, 过拟合, 良好泛化)`*

# %%
def answer_three():
    r2 = answer_two()
    # YOUR CODE HERE
    
    
answer_three()

# %% [markdown]
# ### Question 4 (15 pt)
#
# Training models on high degree polynomial features can result in overfitting. Train two models: a non-regularized LinearRegression model and a Lasso Regression model (with parameters `alpha=0.01`, `max_iter=10000`, `tol=0.1`) on polynomial features of degree 12. Return the $R^2$ score for LinearRegression and Lasso model's test sets.
#
# *This function should return a tuple `(LinearRegression_R2_test_score, Lasso_R2_test_score)`*
#
# ### 问题 4
#
# 在高阶多项式特征上训练模型可能会导致过拟合。训练两个模型：一个非正则化的线性回归模型和一个套索回归模型（参数分别为 `alpha=0.01`、`max_iter=10000` 和 `tol=0.1`），这些模型均使用 12 阶多项式特征。返回线性回归和套索模型测试集的 $R^2$ 得分。
#
# *此函数应返回一个元组 `(LinearRegression_R2_test_score, Lasso_R2_test_score)`*

# %%
def answer_four():
    from sklearn.preprocessing import PolynomialFeatures
    from sklearn.linear_model import Lasso, LinearRegression
    from sklearn.metrics import r2_score
    
    # YOUR CODE HERE


answer_four()

# %% [markdown]
# ### Part 2 - Classification 第二部分 - 分类
#
# For this section of the assignment we will be working with the [UCI Mushroom Data Set](http://archive.ics.uci.edu/ml/datasets/Mushroom?ref=datanews.io) stored in `mushrooms.csv`. The data will be used to trian a model to predict whether or not a mushroom is poisonous. The following attributes are provided:
#
# *Attribute Information:*
#
# 1. cap-shape: bell=b, conical=c, convex=x, flat=f, knobbed=k, sunken=s
# 2. cap-surface: fibrous=f, grooves=g, scaly=y, smooth=s
# 3. cap-color: brown=n, buff=b, cinnamon=c, gray=g, green=r, pink=p, purple=u, red=e, white=w, yellow=y
# 4. bruises?: bruises=t, no=f
# 5. odor: almond=a, anise=l, creosote=c, fishy=y, foul=f, musty=m, none=n, pungent=p, spicy=s
# 6. gill-attachment: attached=a, descending=d, free=f, notched=n
# 7. gill-spacing: close=c, crowded=w, distant=d
# 8. gill-size: broad=b, narrow=n
# 9. gill-color: black=k, brown=n, buff=b, chocolate=h, gray=g, green=r, orange=o, pink=p, purple=u, red=e, white=w, yellow=y
# 10. stalk-shape: enlarging=e, tapering=t
# 11. stalk-root: bulbous=b, club=c, cup=u, equal=e, rhizomorphs=z, rooted=r, missing=?
# 12. stalk-surface-above-ring: fibrous=f, scaly=y, silky=k, smooth=s
# 13. stalk-surface-below-ring: fibrous=f, scaly=y, silky=k, smooth=s
# 14. stalk-color-above-ring: brown=n, buff=b, cinnamon=c, gray=g, orange=o, pink=p, red=e, white=w, yellow=y
# 15. stalk-color-below-ring: brown=n, buff=b, cinnamon=c, gray=g, orange=o, pink=p, red=e, white=w, yellow=y
# 16. veil-type: partial=p, universal=u
# 17. veil-color: brown=n, orange=o, white=w, yellow=y
# 18. ring-number: none=n, one=o, two=t
# 19. ring-type: cobwebby=c, evanescent=e, flaring=f, large=l, none=n, pendant=p, sheathing=s, zone=z
# 20. spore-print-color: black=k, brown=n, buff=b, chocolate=h, green=r, orange=o, purple=u, white=w, yellow=y
# 21. population: abundant=a, clustered=c, numerous=n, scattered=s, several=v, solitary=y
# 22. habitat: grasses=g, leaves=l, meadows=m, paths=p, urban=u, waste=w, woods=d
#
# <br>
#
# The data in the mushrooms dataset is currently encoded with strings. These values will need to be encoded to numeric to work with sklearn. We'll use pd.get_dummies to convert the categorical variables into indicator variables.
#
#
# 本部分作业将使用存储在 `mushrooms.csv` 文件中的 [UCI 蘑菇数据集](http://archive.ics.uci.edu/ml/datasets/Mushroom?ref=datanews.io)。该数据将用于训练一个模型，预测蘑菇是否有毒。提供以下属性：
#
# *属性信息：*
#
# 1. 菌盖形状：钟形=b，圆锥形=c，凸形=x，扁平=f，节状=k，凹陷=s
# 2. 菌盖表面：纤维状=f，凹槽=g，鳞片状=y，光滑=s
# 3. 菌盖颜色：棕色=n，浅黄色=b，肉桂色=c，灰色=g，绿色=r，粉红色=p，紫色=u，红色=e，白色=w，黄色=y
# 4. 是否有瘀伤？：瘀伤=t，无=f
# 5. 气味：杏仁味=a，茴香味=l，杂酚油味=c，鱼腥味=y，臭味=f，霉味=m，无=n，刺鼻味=p，辛辣味=s
# 6. 菌褶附着：附着=a，下垂=d，游离=f，缺口=n
# 7. 菌褶间距：紧密=c拥挤=w，遥远=d
# 8. 菌褶大小：宽=b，窄=n
# 9. 菌褶颜色：黑色=k，棕色=n，浅黄色=b，巧克力色=h，灰色=g，绿色=r，橙色=o，粉色=p，紫色=u，红色=e，白色=w，黄色=y
# 10. 菌柄形状：扩大=e，逐渐变细=t
# 11. 菌柄根：球根状=b，杵状=c，杯状=u，等长=e，根状菌索=z，有根=r，缺失=?
# 12. 环上方的茎表面：纤维状=f，鳞状=y，丝状=k，光滑=s
# 13. 环下方的茎表面：纤维状=f，鳞状=y，丝状=k，光滑=s
# 14. 环上方的茎颜色：棕色=n，浅黄色=b，肉桂色=c，灰色=g，橙色=o，粉红色=p，红色=e，白色=w，黄色=y
# 15. 环下方的茎颜色：棕色=n，浅黄色=b，肉桂色=c，灰色=g，橙色=o，粉红色=p，红色=e，白色=w，黄色=y
# 16. 面纱类型：部分=p，通用=u
# 17. 面纱颜色：棕色=n，橙色=o，白色=w，黄色=y
# 18. 环数：无=n，一=o two=t
# 19. 环状类型：蛛网状=c，消散状=e，喇叭状=f，大状=l，无=n，垂饰状=p，覆盖状=s，区域=z
# 20. 孢子印颜色：黑色=k，棕色=n，浅黄色=b，巧克力色=h，绿色=r，橙色=o，紫色=u，白色=w，黄色=y
# 21. 种群数量：丰富=a，聚集状=c，众多=n，分散状=s，若干=v，孤零零=y
# 22. 栖息地：草类=g，树叶=l，草地=m，小路=p，城市=u，废弃物=w，树林=d
#
# <br>
#
# 蘑菇数据集中的数据目前使用字符串编码。这些值需要编码为数字才能与sklearn一起使用。我们将使用pd.get_dummies将分类变量转换为指示变量。

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split


mush_df = pd.read_csv('mushrooms.csv')
mush_df2 = pd.get_dummies(mush_df)

X_mush = mush_df2.iloc[:,2:]
y_mush = mush_df2.iloc[:,1]


X_train2, X_test2, y_train2, y_test2 = train_test_split(X_mush, y_mush, random_state=0)

# %% [markdown]
# ### Question 5 (15 pt)
#
# For this question, use the `validation_curve` function in `sklearn.model_selection` to determine training and test scores for a Support Vector Classifier (`SVC`) with varying parameter values.
#
# Create an `SVC` with default parameters (i.e. `kernel='rbf', C=1`) and `random_state=0`. Recall that the kernel width of the RBF kernel is controlled using the `gamma` parameter.  Explore the effect of `gamma` on classifier accuracy by using the `validation_curve` function to find the training and test scores for 6 values of `gamma` from `0.0001` to `10` (i.e. `np.logspace(-4,1,6)`).
#
# For each level of `gamma`, `validation_curve` will use 3-fold cross validation (use `cv=3, n_jobs=2` as parameters for `validation_curve`), returning two 6x3 (6 levels of gamma x 3 fits per level) arrays of the scores for the training and test sets in each fold.
#
# Find the mean score across the five models for each level of `gamma` for both arrays, creating two arrays of length 6, and return a tuple with the two arrays.
#
# e.g.
#
# if one of your array of scores is
#
#     array([[ 0.5,  0.4,  0.6],
#            [ 0.7,  0.8,  0.7],
#            [ 0.9,  0.8,  0.8],
#            [ 0.8,  0.7,  0.8],
#            [ 0.7,  0.6,  0.6],
#            [ 0.4,  0.6,  0.5]])
#
# it should then become
#
#     array([ 0.5,  0.73333333,  0.83333333,  0.76666667,  0.63333333, 0.5])
#
# *This function should return a tuple of numpy arrays `(training_scores, test_scores)` where each array in the tuple has shape `(6,)`.*

# %% [markdown]
# ### 问题 5
#
# 对于本题，请使用 `sklearn.model_selection` 中的 `validation_curve` 函数来确定具有不同参数值的支持向量分类器 (`SVC`) 的训练和测试分数。
#
# 创建一个具有默认参数（即 `kernel='rbf', C=1`）和 `random_state=0` 的 `SVC`。回想一下，RBF 核的核宽度由 `gamma` 参数控制。使用 `validation_curve` 函数查找 `gamma` 从 `0.0001` 到 `10` 的 6 个值（即 `np.logspace(-4,1,6)`）的训练和测试分数，探索 `gamma` 对分类器准确率的影响。
#
# 对于 `gamma` 的每个级别，`validation_curve` 将使用三折交叉验证（使用 `cv=3, n_jobs=2` 作为 `validation_curve` 的参数），返回两个 6x3（6 个 gamma 级别 x 每个级别 3 个拟合）数组，其中包含每个级别的训练集和测试集的得分。
#
# 针对这两个数组，求出每个 `gamma` 级别的五个模型的平均得分，创建两个长度为 6 的数组，并返回包含这两个数组的元组。
#
# 例如：
#
# 假设你的某个分数数组是
#
# array([[ 0.5, 0.4, 0.6],
# [ 0.7, 0.8, 0.7],
# [ 0.9, 0.8, 0.8],
# [ 0.8, 0.7, 0.8],
# [ 0.7, 0.6, 0.6],
# [ 0.4, 0.6, 0.5]])
#
# 它应该变成
#
# array([ 0.5, 0.73333333, 0.83333333, 0.76666667, 0.63333333, 0.5])
#
# *此函数应该返回一个由 `(training_scores, test_scores)` 组成的 numpy 数组元组，其中每个数组的形状均为 `(6,)`。*

# %%
def answer_five():
    from sklearn.svm import SVC
    from sklearn.model_selection import validation_curve
    # YOUR CODE HERE

    raise NotImplementedError()

res_six = answer_five()
print(res_six)

# %% [markdown]
# ### Question 6 (15 pt)
#
# Based on the scores from question 5, what gamma value corresponds to a model that is underfitting? What gamma value corresponds to a model that is overfitting? What choice of gamma would provide a model with good generalization performance on this dataset?
#
# (Hint: Try plotting the scores from question 6 to visualize the relationship)
#
# *This function should return a tuple with the degree values in this order: `(Underfitting, Overfitting, Good_Generalization)`*
#
# ### 问题 6
#
# 根据问题 5 中的分数，哪个 Gamma 值对应于欠拟合的模型？哪个 Gamma 值对应于过拟合的模型？哪种 Gamma 值能让模型在这个数据集上获得良好的泛化性能？
#
# （提示：尝试绘制问题 6 中的分数，以直观地展示两者之间的关系）
#
# *此函数应返回一个元组，其度值按以下顺序排列：`(欠拟合, 过拟合, 良好泛化)`*

# %%
def answer_six():
    # YOUR CODE HERE

    raise NotImplementedError()

answer_six()
